# %%
# Inputs we need from the user
# 1. Total food ordered for snacking
# 2. Electricity units spent
# 3. Charge per unit
# 4. Persons living in room/flat

# Output:
# Total amount you’ve to pay is

rent = int(input("Enter your hostel/flat rent: "))
food = int(input("Enter the amount of food ordered: "))
electricity_spend = int(input("Enter the total electricity spend: "))
charge_per_unit = int(input("Enter the charge per unit: "))
persons = int(input("Enter the number of persons living in room/flat: "))

total_bill = electricity_spend * charge_per_unit
output = (food+rent + total_bill) // persons
print("Each person will pay = ", output)
# Out:
# Enter your hostel/flat rent: 5000
# Enter the amount of food ordered: 2000
# Enter the total electricity spend: 300
# Enter the charge per unit: 10
# Enter the number of persons living in room/flat: 3
# Each person will pay =  3333
